# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhAnasuri/Predicting_COVID19_via_CT_Scans/blob/main/KerasModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Notebook was inspired from Yirun Zhang. All snippets taken are credited from him:
https://www.kaggle.com/gogo827jz/covid-19-diagnosis-on-tpu-with-patients-clustering?scriptVersionId=40795779

import os
import gc
import cv2
import math
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Concatenate, Dense, Conv2D, BatchNormalization, Dropout, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score, roc_curve

print("Tensorflow version " + tf.__version__)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Tensorflow version 2.5.0

# %%
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.92.189.178:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.92.189.178:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.92.189.178:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# REPLICAS:  8

# %%
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) 

def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation = cv2.INTER_AREA)

def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear = math.pi * shear / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape( tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3] )
        
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape( tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3] )    
    
    # ZOOM MATRIX
    zoom_matrix = tf.reshape( tf.concat([one/height_zoom,zero,zero, zero,one/width_zoom,zero, zero,zero,one],axis=0),[3,3] )
    
    # SHIFT MATRIX
    shift_matrix = tf.reshape( tf.concat([one,zero,height_shift, zero,one,width_shift, zero,zero,one],axis=0),[3,3] )
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), K.dot(zoom_matrix, shift_matrix))

def transform(image,label):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    DIM = IMAGE_SIZE
    XDIM = DIM%2 #fix for size 331
    
    rot = 15. * tf.random.normal([1],dtype='float32')
    shr = 5. * tf.random.normal([1],dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    w_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    h_shift = 16. * tf.random.normal([1],dtype='float32') 
    w_shift = 16. * tf.random.normal([1],dtype='float32') 
  
    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image,tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3]),label

def get_training_dataset(dataset, do_aug = True):
    if do_aug: 
        dataset = dataset.map(transform, num_parallel_calls = AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(dataset):
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  input/  sample_data/

# %%
# !unzip input
disease_types=['COVID', 'non-COVID']
data_dir = '/content/drive/MyDrive/Covid-19_Dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])      
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
IMAGE_SIZE = 64
X = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values), total = len(train)):
    image = read_image(file)
    if image is not None:
        X[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
X /= 255.
y = train['DiseaseID'].values
print(X.shape)
print(y.shape)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2481.0), HTML(value='')))
# (2481, 64, 64, 3)
# (2481,)

# %%
from sklearn.cluster import KMeans

X0 = X[y == 0].reshape(len(X[y == 0]), -1)
X1 = X[y == 1].reshape(len(X[y == 1]), -1)

k = 50
kmeans = KMeans(k)
cluster0 = kmeans.fit_predict(X0)
cluster1 = kmeans.fit_predict(X1)
cluster1 += k
cluster = np.concatenate([cluster0, cluster1])

# %%
np.random.seed(42)

rows = 5 
cols = 5

fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
for i in range(rows):
    clt = np.random.randint(0, 2 * k)
    clt_idx = np.random.choice(np.where(cluster == clt)[0], cols, replace = True)
    X_clt = X[clt_idx]
    for j in range(cols):
        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])
        ax[i, j].set_title([f'Cluster {clt}'])
        ax[i, j].imshow(X_clt[j])

# %%
train_idx, val_idx = next(GroupShuffleSplit(test_size = 0.2, 
                                            n_splits = 2, 
                                            random_state = 42).split(X, groups = cluster))

X_train, X_val, Y_train, Y_val = X[train_idx], X[val_idx], y[train_idx], y[val_idx]

# %%
BATCH_SIZE = 32 * strategy.num_replicas_in_sync

train_dataset = get_training_dataset(tf.data.Dataset.from_tensor_slices((X_train, Y_train)))
val_dataset = get_validation_dataset(tf.data.Dataset.from_tensor_slices((X_val, Y_val)))

# %%
# EfficientNet models are not applicable on Tensorflow 2.2.0 for TPU
with strategy.scope():

    if not tpu:
        net = tf.keras.applications.EfficientNetB0(include_top = False,
                                                   weights = 'imagenet',
                                                   pooling = None)
    else:
        net = tf.keras.applications.DenseNet121(include_top = False,
                                                weights = 'imagenet',
                                                pooling = None)

    inp = Input(shape = (IMAGE_SIZE, IMAGE_SIZE, 3))
    x = Conv2D(3, (3, 3), padding = 'same')(inp)
    x = net(x)
    x1 = GlobalAveragePooling2D()(x)
    x2 = GlobalMaxPooling2D()(x)
    x = Concatenate()([x1, x2])
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation = 'relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation = 'sigmoid')(x)

    model = Model(inputs = inp, outputs = out)

    metric = tf.keras.metrics.AUC(name = 'auc')
    
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = [metric])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 3)    84          input_2[0][0]
# __________________________________________________________________________________________________
# densenet121 (Functional)        (None, None, None, 1 7037504     conv2d[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           densenet121[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 1024)         0           densenet121[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2048)         0           global_average_pooling2d[0][0]
#                                                                  global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2048)         8192        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            513         dropout_1[0][0]
# ==================================================================================================
# Total params: 8,097,429
# Trainable params: 8,008,661
# Non-trainable params: 88,768
# __________________________________________________________________________________________________

# %%
plot_model(model, 
           show_shapes = True, 
           show_layer_names = True, 
           rankdir = 'TB', 
           expand_nested = False, 
           dpi = 60)

# %%
# Cosine Annealing Learning Rate from 'https://github.com/4uiiurz1/keras-cosine-annealing'
class CosineAnnealingScheduler(Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min=0, verbose=0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        K.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = K.get_value(self.model.optimizer.lr)

# %%
EPOCHS = 100

# earlystopping = EarlyStopping(monitor = 'val_auc', min_delta = 0.001, patience = 10, verbose = 1, mode = 'max', restore_best_weights = True)
# annealer = ReduceLROnPlateau(monitor = 'val_auc', factor = 0.2, patience = 5, verbose = 1, min_lr = 1e-4, mode = 'max')
# checkpoint = ModelCheckpoint('model.h5', monitor = 'val_auc', verbose = 0, mode = 'max', save_best_only = True)
annealer = CosineAnnealingScheduler(EPOCHS, 1e-3, 1e-5)

hist = model.fit(train_dataset,
                 steps_per_epoch = X_train.shape[0] // BATCH_SIZE,
                 epochs = EPOCHS,
                 verbose = 1,
                 callbacks = [annealer],
                 validation_data = val_dataset)
# Out:
# Epoch 1/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.9162 - auc: 0.6399WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0111s vs `on_train_batch_end` time: 6.1811s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0111s vs `on_train_batch_end` time: 6.1811s). Check your callbacks.
# 7/7 [==============================] - 91s 2s/step - loss: 0.9112 - auc: 0.6433 - val_loss: 1.0056 - val_auc: 0.5335
# Epoch 2/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.8073 - auc: 0.7415 - val_loss: 1.3358 - val_auc: 0.4743
# Epoch 3/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.6792 - auc: 0.8059 - val_loss: 3.2293 - val_auc: 0.4897
# Epoch 4/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.6571 - auc: 0.8246 - val_loss: 2.1994 - val_auc: 0.5834
# Epoch 5/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.5393 - auc: 0.8473 - val_loss: 6.8520 - val_auc: 0.5017
# Epoch 6/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.5501 - auc: 0.8461 - val_loss: 9.2532 - val_auc: 0.5000
# Epoch 7/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.5047 - auc: 0.8577 - val_loss: 4.3225 - val_auc: 0.5509
# Epoch 8/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.4650 - auc: 0.8752 - val_loss: 9.5147 - val_auc: 0.5102
# Epoch 9/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.4535 - auc: 0.8877 - val_loss: 7.6558 - val_auc: 0.5627
# Epoch 10/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.4655 - auc: 0.8807 - val_loss: 20.7045 - val_auc: 0.5695
# Epoch 11/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.4322 - auc: 0.8907 - val_loss: 19.0981 - val_auc: 0.5966
# Epoch 12/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.4049 - auc: 0.8995 - val_loss: 34.8279 - val_auc: 0.5390
# Epoch 13/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.4085 - auc: 0.9080 - val_loss: 42.7345 - val_auc: 0.5746
# Epoch 14/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.4166 - auc: 0.9044 - val_loss: 20.4564 - val_auc: 0.6203
# Epoch 15/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.3795 - auc: 0.9085 - val_loss: 6.5868 - val_auc: 0.7189
# Epoch 16/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.3532 - auc: 0.9214 - val_loss: 3.5959 - val_auc: 0.7799
# Epoch 17/100
# 7/7 [==============================] - 2s 290ms/step - loss: 0.3267 - auc: 0.9334 - val_loss: 5.1829 - val_auc: 0.7588
# Epoch 18/100
# 7/7 [==============================] - 2s 395ms/step - loss: 0.3542 - auc: 0.9283 - val_loss: 15.7109 - val_auc: 0.7356
# Epoch 19/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.2865 - auc: 0.9488 - val_loss: 15.0739 - val_auc: 0.7600
# Epoch 20/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.3648 - auc: 0.9212 - val_loss: 20.0688 - val_auc: 0.7504
# Epoch 21/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.3473 - auc: 0.9250 - val_loss: 20.3129 - val_auc: 0.7860
# Epoch 22/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.3158 - auc: 0.9377 - val_loss: 27.9766 - val_auc: 0.7898
# Epoch 23/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.3167 - auc: 0.9352 - val_loss: 20.8065 - val_auc: 0.8119
# Epoch 24/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.2912 - auc: 0.9485 - val_loss: 3.1137 - val_auc: 0.8705
# Epoch 25/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.3125 - auc: 0.9396 - val_loss: 4.4018 - val_auc: 0.8491
# Epoch 26/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.2602 - auc: 0.9571 - val_loss: 4.5353 - val_auc: 0.8855
# Epoch 27/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.2953 - auc: 0.9463 - val_loss: 10.7707 - val_auc: 0.8327
# Epoch 28/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.2514 - auc: 0.9600 - val_loss: 9.2074 - val_auc: 0.8558
# Epoch 29/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.2698 - auc: 0.9551 - val_loss: 10.2079 - val_auc: 0.8426
# Epoch 30/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.2644 - auc: 0.9553 - val_loss: 7.3844 - val_auc: 0.8176
# Epoch 31/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.2934 - auc: 0.9471 - val_loss: 4.9443 - val_auc: 0.8736
# Epoch 32/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.2524 - auc: 0.9601 - val_loss: 10.6347 - val_auc: 0.7970
# Epoch 33/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.2425 - auc: 0.9633 - val_loss: 5.0347 - val_auc: 0.8524
# Epoch 34/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2737 - auc: 0.9530 - val_loss: 3.0923 - val_auc: 0.9030
# Epoch 35/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.2566 - auc: 0.9592 - val_loss: 2.8803 - val_auc: 0.9069
# Epoch 36/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.2659 - auc: 0.9564 - val_loss: 1.8298 - val_auc: 0.9164
# Epoch 37/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.2380 - auc: 0.9639 - val_loss: 1.9142 - val_auc: 0.9124
# Epoch 38/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.2329 - auc: 0.9673 - val_loss: 0.7621 - val_auc: 0.9630
# Epoch 39/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.2037 - auc: 0.9749 - val_loss: 0.7406 - val_auc: 0.9628
# Epoch 40/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1983 - auc: 0.9758 - val_loss: 0.2698 - val_auc: 0.9778
# Epoch 41/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.2272 - auc: 0.9688 - val_loss: 0.2486 - val_auc: 0.9739
# Epoch 42/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.2463 - auc: 0.9635 - val_loss: 0.2725 - val_auc: 0.9870
# Epoch 43/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.2097 - auc: 0.9736 - val_loss: 0.7211 - val_auc: 0.9593
# Epoch 44/100
# 7/7 [==============================] - 3s 417ms/step - loss: 0.2045 - auc: 0.9742 - val_loss: 0.3676 - val_auc: 0.9830
# Epoch 45/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.2040 - auc: 0.9744 - val_loss: 0.3510 - val_auc: 0.9810
# Epoch 46/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.2102 - auc: 0.9726 - val_loss: 0.2413 - val_auc: 0.9862
# Epoch 47/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.2032 - auc: 0.9744 - val_loss: 0.2200 - val_auc: 0.9816
# Epoch 48/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1746 - auc: 0.9815 - val_loss: 0.3866 - val_auc: 0.9434
# Epoch 49/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1695 - auc: 0.9828 - val_loss: 0.3260 - val_auc: 0.9700
# Epoch 50/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.1894 - auc: 0.9770 - val_loss: 0.3561 - val_auc: 0.9353
# Epoch 51/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.1762 - auc: 0.9808 - val_loss: 0.5098 - val_auc: 0.9354
# Epoch 52/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.2058 - auc: 0.9740 - val_loss: 0.3019 - val_auc: 0.9716
# Epoch 53/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1817 - auc: 0.9806 - val_loss: 0.3496 - val_auc: 0.9587
# Epoch 54/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.1596 - auc: 0.9843 - val_loss: 0.4221 - val_auc: 0.9746
# Epoch 55/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1430 - auc: 0.9873 - val_loss: 0.3411 - val_auc: 0.9690
# Epoch 56/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.1804 - auc: 0.9792 - val_loss: 0.4250 - val_auc: 0.9706
# Epoch 57/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.1764 - auc: 0.9802 - val_loss: 0.2376 - val_auc: 0.9879
# Epoch 58/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1587 - auc: 0.9845 - val_loss: 0.1666 - val_auc: 0.9877
# Epoch 59/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.1306 - auc: 0.9897 - val_loss: 0.1626 - val_auc: 0.9852
# Epoch 60/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.1412 - auc: 0.9867 - val_loss: 0.2605 - val_auc: 0.9726
# Epoch 61/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.1436 - auc: 0.9873 - val_loss: 0.2554 - val_auc: 0.9708
# Epoch 62/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.1307 - auc: 0.9896 - val_loss: 0.1947 - val_auc: 0.9850
# Epoch 63/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.1406 - auc: 0.9883 - val_loss: 0.3328 - val_auc: 0.9772
# Epoch 64/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.1630 - auc: 0.9841 - val_loss: 0.3496 - val_auc: 0.9764
# Epoch 65/100
# 7/7 [==============================] - 2s 250ms/step - loss: 0.1230 - auc: 0.9910 - val_loss: 0.4029 - val_auc: 0.9573
# Epoch 66/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1366 - auc: 0.9884 - val_loss: 0.3912 - val_auc: 0.9636
# Epoch 67/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1211 - auc: 0.9906 - val_loss: 0.3872 - val_auc: 0.9840
# Epoch 68/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.1040 - auc: 0.9940 - val_loss: 0.2895 - val_auc: 0.9896
# Epoch 69/100
# 7/7 [==============================] - 3s 410ms/step - loss: 0.1426 - auc: 0.9893 - val_loss: 0.1657 - val_auc: 0.9906
# Epoch 70/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.1136 - auc: 0.9921 - val_loss: 0.2900 - val_auc: 0.9901
# Epoch 71/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.1352 - auc: 0.9884 - val_loss: 0.2445 - val_auc: 0.9929
# Epoch 72/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.1221 - auc: 0.9913 - val_loss: 0.1681 - val_auc: 0.9906
# Epoch 73/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.1310 - auc: 0.9890 - val_loss: 0.1814 - val_auc: 0.9919
# Epoch 74/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.1096 - auc: 0.9928 - val_loss: 0.1690 - val_auc: 0.9916
# Epoch 75/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1081 - auc: 0.9927 - val_loss: 0.1798 - val_auc: 0.9934
# Epoch 76/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.1064 - auc: 0.9933 - val_loss: 0.1549 - val_auc: 0.9946
# Epoch 77/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.1066 - auc: 0.9933 - val_loss: 0.1074 - val_auc: 0.9944
# Epoch 78/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0948 - auc: 0.9943 - val_loss: 0.1044 - val_auc: 0.9939
# Epoch 79/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.1143 - auc: 0.9918 - val_loss: 0.1152 - val_auc: 0.9932
# Epoch 80/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.1084 - auc: 0.9925 - val_loss: 0.1433 - val_auc: 0.9920
# Epoch 81/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0885 - auc: 0.9950 - val_loss: 0.1471 - val_auc: 0.9916
# Epoch 82/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0862 - auc: 0.9958 - val_loss: 0.1678 - val_auc: 0.9893
# Epoch 83/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0875 - auc: 0.9953 - val_loss: 0.1598 - val_auc: 0.9917
# Epoch 84/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0718 - auc: 0.9971 - val_loss: 0.1495 - val_auc: 0.9926
# Epoch 85/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0903 - auc: 0.9951 - val_loss: 0.1521 - val_auc: 0.9921
# Epoch 86/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0734 - auc: 0.9965 - val_loss: 0.1564 - val_auc: 0.9910
# Epoch 87/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0844 - auc: 0.9960 - val_loss: 0.1362 - val_auc: 0.9926
# Epoch 88/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0938 - auc: 0.9946 - val_loss: 0.1389 - val_auc: 0.9919
# Epoch 89/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0799 - auc: 0.9961 - val_loss: 0.1514 - val_auc: 0.9917
# Epoch 90/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0989 - auc: 0.9938 - val_loss: 0.1439 - val_auc: 0.9925
# Epoch 91/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0850 - auc: 0.9951 - val_loss: 0.1361 - val_auc: 0.9926
# Epoch 92/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0840 - auc: 0.9958 - val_loss: 0.1404 - val_auc: 0.9924
# Epoch 93/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0939 - auc: 0.9937 - val_loss: 0.1557 - val_auc: 0.9920
# Epoch 94/100
# 7/7 [==============================] - 3s 425ms/step - loss: 0.0944 - auc: 0.9939 - val_loss: 0.1653 - val_auc: 0.9914
# Epoch 95/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.1024 - auc: 0.9931 - val_loss: 0.1675 - val_auc: 0.9912
# Epoch 96/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0887 - auc: 0.9946 - val_loss: 0.1676 - val_auc: 0.9900
# Epoch 97/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0773 - auc: 0.9962 - val_loss: 0.1655 - val_auc: 0.9905
# Epoch 98/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0831 - auc: 0.9956 - val_loss: 0.1652 - val_auc: 0.9910
# Epoch 99/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0885 - auc: 0.9950 - val_loss: 0.1665 - val_auc: 0.9911
# Epoch 100/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0702 - auc: 0.9969 - val_loss: 0.1651 - val_auc: 0.9911

# %%
# AUC score is better than accuracy if the classes are imbalanced
print('Best Validation AUC:\t', max(hist.history['val_auc']))

auc = hist.history['auc']
val_auc = hist.history['val_auc']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(len(auc))

plt.figure(figsize = (7, 5))
plt.title('Training and Validation AUC')
plt.plot(epochs, auc, 'r', label = 'Train')
plt.plot(epochs, val_auc, 'b', label = 'Val')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend(loc = 0)
plt.show()
# Out:
# Best Validation AUC:	 0.9946483969688416

# %%
pred_proba = model.predict(X_val)
auc_score = roc_auc_score(Y_val, pred_proba)
fpr, tpr, th = roc_curve(Y_val, pred_proba)
print('AUC Score:\t', auc_score)
# Out:
# AUC Score:	 0.9921683226183518

# %%
plt.figure(figsize = (7, 5))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'r')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive')
plt.ylabel('True Positive')
plt.legend(loc = 4)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
def threshold_optimisation(y_true, y_pred, thresholds):
    best_th = thresholds[0]
    best_acc = accuracy_score(y_true, np.where(y_pred > thresholds[0], 1, 0))
    for th in thresholds[1:]:
        acc = accuracy_score(y_true, np.where(y_pred > th, 1, 0))
        if acc > best_acc:
            best_th = th
            best_acc = acc
    return best_acc, best_th

# %%
best_acc, best_th = threshold_optimisation(Y_val, pred_proba, th)
print('Best Accuracy:\t', best_acc)
print('Best Threshold:\t', best_th)
# Out:
# Best Accuracy:	 0.9618473895582329
# Best Threshold:	 0.78383255
